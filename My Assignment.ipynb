# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Elijah Yeboah**

# %% [markdown]
# _I am interested in data science because I want to be able to use data to solve daily human needs_

# %% [markdown]
# <h3>The code is supposed to test a simple mathematics

# %%
a = 3
b = 2

# %%
print(a+b)
# Out:
# 5

# %% [markdown]
# - mango
# - orange
# - coconut

# %% [markdown]
# |Name|Sex|
# |-----|-----|
# |_Elijah Yeboah_|**Male**|

# %% [markdown]
# __[ibm.com](http://ibm.com)__
